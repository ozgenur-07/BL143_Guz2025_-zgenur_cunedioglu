# %% [markdown]
# <a href="https://colab.research.google.com/github/ozgenur-07/BL143_Guz2025_-zgenur_cunedioglu/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Karşılaştırma Operatörleri
print (5<7)
print (5<=8)
print (5>9)
print (6>=2)
print (8=="8") #eşittir
print ("a"!="A")#eşit değildir
print (400==4e2)
# Out:
# True
# True
# False
# True
# False
# True
# True

# %%
#Mantık Operatörü
print (True and False)
print ("A"=="b" and  "Mahir"== "Mâhir") #False
print (8 !=5+2 or 3**2==9) #True
print (not" a" ! ="e") #False
print (not (3=>3 and 2 <5**0)) #
# Out:
#   File "/tmp/ipython-input-1370045729.py", line 5
#     print (not" a" ! ="e") #False
#                    ^
# SyntaxError: invalid syntax

# %%
print(2**5+8%3)
# Out:
# 34
